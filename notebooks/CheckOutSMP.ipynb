# %%
from snowmicropyn import Profile,density_ssa
import matplotlib.pyplot as plt

p = Profile.load('../data/SMP/SNEX20_SMP_S19M1174_2N13_20200206.PNT',)

plt.plot(p.samples.distance, p.samples.force)
# Prettify our plot a bit
plt.title(p.name)
plt.ylabel('Force [N]')
plt.xlabel('Depth [mm]')
plt.show()
# Out:
# Latitude value -99999.0 invalid, replacing by None
# Longitude value -99999.0 invalid, replacing by None

# %%
density_ssa.calc(p.samples, coeff_model='C2020')
# Out:
# /Users/mtd/opt/anaconda3/envs/snowex-microstructure/lib/python3.8/site-packages/snowmicropyn-1.0.1-py3.8.egg/snowmicropyn/loewe2012.py:58: RuntimeWarning: invalid value encountered in double_scalars
#   delta = -(3. / 2) * c_f[n - 1] / (c_f[n] - c_f[n - 1]) * spatial_res
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-2-9819fc39d7f1> in <module>
# ----> 1 density_ssa.calc(p.samples, coeff_model='C2020')
#
# ~/opt/anaconda3/envs/snowex-microstructure/lib/python3.8/site-packages/snowmicropyn-1.0.1-py3.8.egg/snowmicropyn/density_ssa.py in calc(samples, coeff_model, window, overlap)
#     105         samples.loc[samples['force'] < 0, 'force'] = np.nan
#     106         samples.force.interpolate(method='linear', inplace=True)
# --> 107         sn = snowmicropyn.loewe2012.calc(samples, window, overlap)
#     108
#     109     result = []
#
# ~/opt/anaconda3/envs/snowex-microstructure/lib/python3.8/site-packages/snowmicropyn-1.0.1-py3.8.egg/snowmicropyn/loewe2012.py in calc(samples, window, overlap)
#      87     for center, chunk in chunks:
#      88         f_median = np.median(chunk.force)
# ---> 89         sn = calc_step(spatial_res, chunk.force)
#      90         result.append((center, f_median) + sn)
#      91     return pd.DataFrame(result, columns=['distance', 'force_median', 'L2012_lambda', 'L2012_f0',
#
# ~/opt/anaconda3/envs/snowex-microstructure/lib/python3.8/site-packages/snowmicropyn-1.0.1-py3.8.egg/snowmicropyn/loewe2012.py in calc_step(spatial_res, forces, cone_area)
#      59
#      60     # Equation 12 in publication
# ---> 61     lambda_ = (4. / 3) * (k1 ** 2) / k2 / delta  # Intensity
#      62     f0 = (3. / 2) * k2 / k1
#      63
#
# ZeroDivisionError: float division by zero
